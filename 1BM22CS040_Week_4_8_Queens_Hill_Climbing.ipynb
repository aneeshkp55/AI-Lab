# %%
N = 8

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(N):
            if i != j:
                new_state = state[:]
                new_state[i] = j
                neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)

    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")

        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost
        if next_cost == current_cost:
            break
        else:
            current_state, current_cost = next_state, next_cost
        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

initial_state = list(map(int, input("Enter initial state as 8 space-separated integers (0 to 7): ").split()))
solution_state, solution_cost = hillClimbing(initial_state)
print("\nFinal Results")
print("Initial State:", initial_state)
print("Final State (Solution):", solution_state)
print("Final Cost (Attacking Pairs):", solution_cost)

if solution_cost == 0:
    print("Solution found!")
else:
    print("Local optimum reached, but no solution.")
# Out:
# Enter initial state as 8 space-separated integers (0 to 7): 0 3 4 6 7 1 2 5
#
# Iteration 0
# Current State: [0, 3, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [1, 3, 4, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [2, 3, 4, 6, 7, 1, 2, 5], Cost: 7
# Neighbour: [3, 3, 4, 6, 7, 1, 2, 5], Cost: 7
# Neighbour: [4, 3, 4, 6, 7, 1, 2, 5], Cost: 6
# Neighbour: [5, 3, 4, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [6, 3, 4, 6, 7, 1, 2, 5], Cost: 7
# Neighbour: [7, 3, 4, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 0, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 2, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 4, 4, 6, 7, 1, 2, 5], Cost: 6
# Neighbour: [0, 5, 4, 6, 7, 1, 2, 5], Cost: 6
# Neighbour: [0, 6, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 7, 4, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 0, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 3, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 5, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 6, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 7, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 0, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 1, 7, 1, 2, 5], Cost: 6
# Neighbour: [0, 3, 4, 2, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 4, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 5, 7, 1, 2, 5], Cost: 7
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 7, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 0, 1, 2, 5], Cost: 7
# Neighbour: [0, 3, 4, 6, 1, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 2, 1, 2, 5], Cost: 7
# Neighbour: [0, 3, 4, 6, 3, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 5, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 4, 6, 6, 1, 2, 5], Cost: 6
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 7, 0, 2, 5], Cost: 3
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 7, 2, 2, 5], Cost: 3
# Neighbour: [0, 3, 4, 6, 7, 3, 2, 5], Cost: 5
# Neighbour: [0, 3, 4, 6, 7, 4, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 7, 6, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 7, 7, 2, 5], Cost: 6
# Neighbour: [0, 3, 4, 6, 7, 1, 0, 5], Cost: 6
# Neighbour: [0, 3, 4, 6, 7, 1, 1, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 7, 1, 3, 5], Cost: 5
# Neighbour: [0, 3, 4, 6, 7, 1, 4, 5], Cost: 5
# Neighbour: [0, 3, 4, 6, 7, 1, 5, 5], Cost: 5
# Neighbour: [0, 3, 4, 6, 7, 1, 7, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 0], Cost: 5
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 1], Cost: 6
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 2], Cost: 6
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 3], Cost: 7
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 4], Cost: 6
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 6], Cost: 5
#
# Iteration 1
# Current State: [0, 3, 1, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [1, 3, 1, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [2, 3, 1, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [3, 3, 1, 6, 7, 1, 2, 5], Cost: 7
# Neighbour: [4, 3, 1, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [5, 3, 1, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [6, 3, 1, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [7, 3, 1, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 0, 1, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 2, 1, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 4, 1, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 5, 1, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 6, 1, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 7, 1, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 0, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 3, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 4, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 5, 6, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 6, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 7, 6, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 0, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 1, 7, 1, 2, 5], Cost: 6
# Neighbour: [0, 3, 1, 2, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 5, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 7, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 6, 0, 1, 2, 5], Cost: 6
# Neighbour: [0, 3, 1, 6, 1, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 2, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 1, 6, 3, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 5, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 6, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 6, 7, 0, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 6, 7, 2, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 6, 7, 3, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 7, 4, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 6, 7, 6, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 6, 7, 7, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 7, 1, 0, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 7, 1, 1, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 6, 7, 1, 3, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 7, 1, 4, 5], Cost: 3
# Neighbour: [0, 3, 1, 6, 7, 1, 5, 5], Cost: 5
# Neighbour: [0, 3, 1, 6, 7, 1, 7, 5], Cost: 3
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 0], Cost: 4
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 1], Cost: 6
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 2], Cost: 5
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 3], Cost: 6
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 4], Cost: 4
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 6], Cost: 5
#
# Iteration 2
# Current State: [0, 3, 1, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [1, 3, 1, 4, 7, 1, 2, 5], Cost: 5
# Neighbour: [2, 3, 1, 4, 7, 1, 2, 5], Cost: 4
# Neighbour: [3, 3, 1, 4, 7, 1, 2, 5], Cost: 5
# Neighbour: [4, 3, 1, 4, 7, 1, 2, 5], Cost: 4
# Neighbour: [5, 3, 1, 4, 7, 1, 2, 5], Cost: 3
# Neighbour: [6, 3, 1, 4, 7, 1, 2, 5], Cost: 3
# Neighbour: [7, 3, 1, 4, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 0, 1, 4, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 2, 1, 4, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [0, 4, 1, 4, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 5, 1, 4, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 6, 1, 4, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 7, 1, 4, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 0, 4, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [0, 3, 3, 4, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 4, 4, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 5, 4, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 6, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [0, 3, 7, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 0, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 1, 7, 1, 2, 5], Cost: 6
# Neighbour: [0, 3, 1, 2, 7, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 5, 7, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 1, 6, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 7, 7, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 0, 1, 2, 5], Cost: 6
# Neighbour: [0, 3, 1, 4, 1, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 2, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 1, 4, 3, 1, 2, 5], Cost: 5
# Neighbour: [0, 3, 1, 4, 5, 1, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 6, 1, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 5], Cost: 1
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 2, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 3, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 4, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 6, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 7, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 1, 0, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 1, 1, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 1, 3, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 1, 4, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 1, 5, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 1, 7, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 0], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 1], Cost: 5
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 2], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 3], Cost: 5
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 4], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 6], Cost: 3
#
# Iteration 3
# Current State: [0, 3, 1, 4, 7, 0, 2, 5], Cost: 1
# Neighbour: [1, 3, 1, 4, 7, 0, 2, 5], Cost: 2
# Neighbour: [2, 3, 1, 4, 7, 0, 2, 5], Cost: 2
# Neighbour: [3, 3, 1, 4, 7, 0, 2, 5], Cost: 3
# Neighbour: [4, 3, 1, 4, 7, 0, 2, 5], Cost: 2
# Neighbour: [5, 3, 1, 4, 7, 0, 2, 5], Cost: 2
# Neighbour: [6, 3, 1, 4, 7, 0, 2, 5], Cost: 0
# Neighbour: [7, 3, 1, 4, 7, 0, 2, 5], Cost: 2
# Neighbour: [0, 0, 1, 4, 7, 0, 2, 5], Cost: 4
# Neighbour: [0, 2, 1, 4, 7, 0, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 5], Cost: 1
# Neighbour: [0, 4, 1, 4, 7, 0, 2, 5], Cost: 4
# Neighbour: [0, 5, 1, 4, 7, 0, 2, 5], Cost: 2
# Neighbour: [0, 6, 1, 4, 7, 0, 2, 5], Cost: 2
# Neighbour: [0, 7, 1, 4, 7, 0, 2, 5], Cost: 3
# Neighbour: [0, 3, 0, 4, 7, 0, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 5], Cost: 1
# Neighbour: [0, 3, 3, 4, 7, 0, 2, 5], Cost: 4
# Neighbour: [0, 3, 4, 4, 7, 0, 2, 5], Cost: 3
# Neighbour: [0, 3, 5, 4, 7, 0, 2, 5], Cost: 4
# Neighbour: [0, 3, 6, 4, 7, 0, 2, 5], Cost: 2
# Neighbour: [0, 3, 7, 4, 7, 0, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 0, 7, 0, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 1, 7, 0, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 2, 7, 0, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 5], Cost: 1
# Neighbour: [0, 3, 1, 5, 7, 0, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 6, 7, 0, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 7, 7, 0, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 0, 0, 2, 5], Cost: 5
# Neighbour: [0, 3, 1, 4, 1, 0, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 2, 0, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 3, 0, 2, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 5, 0, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 6, 0, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 5], Cost: 1
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 5], Cost: 1
# Neighbour: [0, 3, 1, 4, 7, 1, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 2, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 3, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 4, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 6, 2, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 7, 2, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 0, 0, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 0, 1, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 5], Cost: 1
# Neighbour: [0, 3, 1, 4, 7, 0, 3, 5], Cost: 2
# Neighbour: [0, 3, 1, 4, 7, 0, 4, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 0, 5, 5], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 0, 7, 5], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 0], Cost: 4
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 1], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 2], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 3], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 4], Cost: 3
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 5], Cost: 1
# Neighbour: [0, 3, 1, 4, 7, 0, 2, 6], Cost: 2
#
# Final Results
# Initial State: [0, 3, 4, 6, 7, 1, 2, 5]
# Final State (Solution): [6, 3, 1, 4, 7, 0, 2, 5]
# Final Cost (Attacking Pairs): 0
# Solution found!

# %%
N = 8

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(N):
            if i != j:
                new_state = state[:]
                new_state[i] = j
                neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)

    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")

        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost
        if next_cost == current_cost:
            break
        else:
            current_state, current_cost = next_state, next_cost
        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

initial_state = list(map(int, input("Enter initial state as 8 space-separated integers (0 to 7): ").split()))
solution_state, solution_cost = hillClimbing(initial_state)
print("\nFinal Results")
print("Initial State:", initial_state)
print("Final State (Solution):", solution_state)
print("Final Cost (Attacking Pairs):", solution_cost)

if solution_cost == 0:
    print("Solution found!")
else:
    print("Local optimum reached, but no solution.")
# Out:
# Enter initial state as 8 space-separated integers (0 to 7): 1 1 1 1 1 1 1 1
#
# Iteration 0
# Current State: [1, 1, 1, 1, 1, 1, 1, 1], Cost: 28
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 1], Cost: 28
# Neighbour: [2, 1, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [3, 1, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [4, 1, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [5, 1, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [6, 1, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [7, 1, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 0, 1, 1, 1, 1, 1, 1], Cost: 23
# Neighbour: [1, 2, 1, 1, 1, 1, 1, 1], Cost: 23
# Neighbour: [1, 3, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 4, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 5, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 6, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 7, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 1, 0, 1, 1, 1, 1, 1], Cost: 23
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 1], Cost: 28
# Neighbour: [1, 1, 3, 1, 1, 1, 1, 1], Cost: 23
# Neighbour: [1, 1, 4, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 1, 5, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 1, 6, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 1, 0, 1, 1, 1, 1], Cost: 23
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 1], Cost: 28
# Neighbour: [1, 1, 1, 2, 1, 1, 1, 1], Cost: 23
# Neighbour: [1, 1, 1, 4, 1, 1, 1, 1], Cost: 23
# Neighbour: [1, 1, 1, 5, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 1, 1, 6, 1, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 1, 7, 1, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 1, 1, 0, 1, 1, 1], Cost: 23
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 1], Cost: 28
# Neighbour: [1, 1, 1, 1, 2, 1, 1, 1], Cost: 23
# Neighbour: [1, 1, 1, 1, 3, 1, 1, 1], Cost: 23
# Neighbour: [1, 1, 1, 1, 5, 1, 1, 1], Cost: 22
# Neighbour: [1, 1, 1, 1, 6, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 1, 1, 7, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 1, 1, 1, 0, 1, 1], Cost: 23
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 1], Cost: 28
# Neighbour: [1, 1, 1, 1, 1, 2, 1, 1], Cost: 23
# Neighbour: [1, 1, 1, 1, 1, 3, 1, 1], Cost: 23
# Neighbour: [1, 1, 1, 1, 1, 4, 1, 1], Cost: 22
# Neighbour: [1, 1, 1, 1, 1, 6, 1, 1], Cost: 22
# Neighbour: [1, 1, 1, 1, 1, 7, 1, 1], Cost: 21
# Neighbour: [1, 1, 1, 1, 1, 1, 0, 1], Cost: 23
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 1], Cost: 28
# Neighbour: [1, 1, 1, 1, 1, 1, 2, 1], Cost: 23
# Neighbour: [1, 1, 1, 1, 1, 1, 3, 1], Cost: 22
# Neighbour: [1, 1, 1, 1, 1, 1, 4, 1], Cost: 22
# Neighbour: [1, 1, 1, 1, 1, 1, 5, 1], Cost: 22
# Neighbour: [1, 1, 1, 1, 1, 1, 7, 1], Cost: 22
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 0], Cost: 22
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 1], Cost: 28
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 2], Cost: 22
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 3], Cost: 22
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 4], Cost: 22
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 5], Cost: 22
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 6], Cost: 22
#
# Iteration 1
# Current State: [1, 1, 7, 1, 1, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 1], Cost: 21
# Neighbour: [2, 1, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 1], Cost: 15
# Neighbour: [4, 1, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [5, 1, 7, 1, 1, 1, 1, 1], Cost: 17
# Neighbour: [6, 1, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [7, 1, 7, 1, 1, 1, 1, 1], Cost: 17
# Neighbour: [1, 0, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [1, 2, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [1, 3, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [1, 4, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [1, 5, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [1, 6, 7, 1, 1, 1, 1, 1], Cost: 17
# Neighbour: [1, 7, 7, 1, 1, 1, 1, 1], Cost: 17
# Neighbour: [1, 1, 0, 1, 1, 1, 1, 1], Cost: 23
# Neighbour: [1, 1, 1, 1, 1, 1, 1, 1], Cost: 28
# Neighbour: [1, 1, 3, 1, 1, 1, 1, 1], Cost: 23
# Neighbour: [1, 1, 4, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 1, 5, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 1, 6, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 7, 0, 1, 1, 1, 1], Cost: 16
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 7, 2, 1, 1, 1, 1], Cost: 16
# Neighbour: [1, 1, 7, 4, 1, 1, 1, 1], Cost: 17
# Neighbour: [1, 1, 7, 5, 1, 1, 1, 1], Cost: 16
# Neighbour: [1, 1, 7, 6, 1, 1, 1, 1], Cost: 16
# Neighbour: [1, 1, 7, 7, 1, 1, 1, 1], Cost: 16
# Neighbour: [1, 1, 7, 1, 0, 1, 1, 1], Cost: 17
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 7, 1, 2, 1, 1, 1], Cost: 17
# Neighbour: [1, 1, 7, 1, 3, 1, 1, 1], Cost: 16
# Neighbour: [1, 1, 7, 1, 5, 1, 1, 1], Cost: 17
# Neighbour: [1, 1, 7, 1, 6, 1, 1, 1], Cost: 15
# Neighbour: [1, 1, 7, 1, 7, 1, 1, 1], Cost: 16
# Neighbour: [1, 1, 7, 1, 1, 0, 1, 1], Cost: 17
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 7, 1, 1, 2, 1, 1], Cost: 17
# Neighbour: [1, 1, 7, 1, 1, 3, 1, 1], Cost: 17
# Neighbour: [1, 1, 7, 1, 1, 4, 1, 1], Cost: 16
# Neighbour: [1, 1, 7, 1, 1, 6, 1, 1], Cost: 16
# Neighbour: [1, 1, 7, 1, 1, 7, 1, 1], Cost: 16
# Neighbour: [1, 1, 7, 1, 1, 1, 0, 1], Cost: 17
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 7, 1, 1, 1, 2, 1], Cost: 17
# Neighbour: [1, 1, 7, 1, 1, 1, 3, 1], Cost: 17
# Neighbour: [1, 1, 7, 1, 1, 1, 4, 1], Cost: 16
# Neighbour: [1, 1, 7, 1, 1, 1, 5, 1], Cost: 15
# Neighbour: [1, 1, 7, 1, 1, 1, 7, 1], Cost: 17
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 0], Cost: 16
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 1], Cost: 21
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 2], Cost: 17
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 3], Cost: 16
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 4], Cost: 16
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 5], Cost: 16
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 6], Cost: 15
#
# Iteration 2
# Current State: [3, 1, 7, 1, 1, 1, 1, 1], Cost: 15
# Neighbour: [1, 1, 7, 1, 1, 1, 1, 1], Cost: 21
# Neighbour: [2, 1, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 1], Cost: 15
# Neighbour: [4, 1, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [5, 1, 7, 1, 1, 1, 1, 1], Cost: 17
# Neighbour: [6, 1, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [7, 1, 7, 1, 1, 1, 1, 1], Cost: 17
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [3, 2, 7, 1, 1, 1, 1, 1], Cost: 11
# Neighbour: [3, 3, 7, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 4, 7, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 5, 7, 1, 1, 1, 1, 1], Cost: 11
# Neighbour: [3, 6, 7, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 7, 7, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 1, 0, 1, 1, 1, 1, 1], Cost: 17
# Neighbour: [3, 1, 1, 1, 1, 1, 1, 1], Cost: 22
# Neighbour: [3, 1, 3, 1, 1, 1, 1, 1], Cost: 17
# Neighbour: [3, 1, 4, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [3, 1, 5, 1, 1, 1, 1, 1], Cost: 17
# Neighbour: [3, 1, 6, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 1], Cost: 15
# Neighbour: [3, 1, 7, 0, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 1], Cost: 15
# Neighbour: [3, 1, 7, 2, 1, 1, 1, 1], Cost: 11
# Neighbour: [3, 1, 7, 4, 1, 1, 1, 1], Cost: 11
# Neighbour: [3, 1, 7, 5, 1, 1, 1, 1], Cost: 11
# Neighbour: [3, 1, 7, 6, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 1, 7, 7, 1, 1, 1, 1], Cost: 11
# Neighbour: [3, 1, 7, 1, 0, 1, 1, 1], Cost: 12
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 1], Cost: 15
# Neighbour: [3, 1, 7, 1, 2, 1, 1, 1], Cost: 12
# Neighbour: [3, 1, 7, 1, 3, 1, 1, 1], Cost: 12
# Neighbour: [3, 1, 7, 1, 5, 1, 1, 1], Cost: 11
# Neighbour: [3, 1, 7, 1, 6, 1, 1, 1], Cost: 10
# Neighbour: [3, 1, 7, 1, 7, 1, 1, 1], Cost: 12
# Neighbour: [3, 1, 7, 1, 1, 0, 1, 1], Cost: 12
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 1], Cost: 15
# Neighbour: [3, 1, 7, 1, 1, 2, 1, 1], Cost: 12
# Neighbour: [3, 1, 7, 1, 1, 3, 1, 1], Cost: 13
# Neighbour: [3, 1, 7, 1, 1, 4, 1, 1], Cost: 11
# Neighbour: [3, 1, 7, 1, 1, 6, 1, 1], Cost: 10
# Neighbour: [3, 1, 7, 1, 1, 7, 1, 1], Cost: 11
# Neighbour: [3, 1, 7, 1, 1, 1, 0, 1], Cost: 12
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 1], Cost: 15
# Neighbour: [3, 1, 7, 1, 1, 1, 2, 1], Cost: 12
# Neighbour: [3, 1, 7, 1, 1, 1, 3, 1], Cost: 13
# Neighbour: [3, 1, 7, 1, 1, 1, 4, 1], Cost: 11
# Neighbour: [3, 1, 7, 1, 1, 1, 5, 1], Cost: 10
# Neighbour: [3, 1, 7, 1, 1, 1, 7, 1], Cost: 11
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 0], Cost: 11
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 1], Cost: 15
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 2], Cost: 12
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 3], Cost: 12
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 4], Cost: 11
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 5], Cost: 11
# Neighbour: [3, 1, 7, 1, 1, 1, 1, 6], Cost: 10
#
# Iteration 3
# Current State: [3, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [1, 0, 7, 1, 1, 1, 1, 1], Cost: 16
# Neighbour: [2, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [4, 0, 7, 1, 1, 1, 1, 1], Cost: 11
# Neighbour: [5, 0, 7, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [6, 0, 7, 1, 1, 1, 1, 1], Cost: 11
# Neighbour: [7, 0, 7, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [3, 2, 7, 1, 1, 1, 1, 1], Cost: 11
# Neighbour: [3, 3, 7, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 4, 7, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 5, 7, 1, 1, 1, 1, 1], Cost: 11
# Neighbour: [3, 6, 7, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 7, 7, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 0, 0, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 0, 1, 1, 1, 1, 1, 1], Cost: 17
# Neighbour: [3, 0, 3, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 0, 4, 1, 1, 1, 1, 1], Cost: 11
# Neighbour: [3, 0, 5, 1, 1, 1, 1, 1], Cost: 12
# Neighbour: [3, 0, 6, 1, 1, 1, 1, 1], Cost: 11
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [3, 0, 7, 0, 1, 1, 1, 1], Cost: 9
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [3, 0, 7, 2, 1, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 7, 4, 1, 1, 1, 1], Cost: 7
# Neighbour: [3, 0, 7, 5, 1, 1, 1, 1], Cost: 7
# Neighbour: [3, 0, 7, 6, 1, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 7, 7, 1, 1, 1, 1], Cost: 7
# Neighbour: [3, 0, 7, 1, 0, 1, 1, 1], Cost: 9
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [3, 0, 7, 1, 2, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 7, 1, 3, 1, 1, 1], Cost: 9
# Neighbour: [3, 0, 7, 1, 5, 1, 1, 1], Cost: 7
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 1], Cost: 6
# Neighbour: [3, 0, 7, 1, 7, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 7, 1, 1, 0, 1, 1], Cost: 9
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [3, 0, 7, 1, 1, 2, 1, 1], Cost: 8
# Neighbour: [3, 0, 7, 1, 1, 3, 1, 1], Cost: 9
# Neighbour: [3, 0, 7, 1, 1, 4, 1, 1], Cost: 8
# Neighbour: [3, 0, 7, 1, 1, 6, 1, 1], Cost: 6
# Neighbour: [3, 0, 7, 1, 1, 7, 1, 1], Cost: 7
# Neighbour: [3, 0, 7, 1, 1, 1, 0, 1], Cost: 9
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [3, 0, 7, 1, 1, 1, 2, 1], Cost: 8
# Neighbour: [3, 0, 7, 1, 1, 1, 3, 1], Cost: 9
# Neighbour: [3, 0, 7, 1, 1, 1, 4, 1], Cost: 7
# Neighbour: [3, 0, 7, 1, 1, 1, 5, 1], Cost: 7
# Neighbour: [3, 0, 7, 1, 1, 1, 7, 1], Cost: 7
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 0], Cost: 8
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 2], Cost: 8
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 3], Cost: 8
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 4], Cost: 7
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 5], Cost: 7
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 6], Cost: 7
#
# Iteration 4
# Current State: [3, 0, 7, 1, 6, 1, 1, 1], Cost: 6
# Neighbour: [1, 0, 7, 1, 6, 1, 1, 1], Cost: 11
# Neighbour: [2, 0, 7, 1, 6, 1, 1, 1], Cost: 7
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 1], Cost: 6
# Neighbour: [4, 0, 7, 1, 6, 1, 1, 1], Cost: 7
# Neighbour: [5, 0, 7, 1, 6, 1, 1, 1], Cost: 7
# Neighbour: [6, 0, 7, 1, 6, 1, 1, 1], Cost: 8
# Neighbour: [7, 0, 7, 1, 6, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 1], Cost: 6
# Neighbour: [3, 2, 7, 1, 6, 1, 1, 1], Cost: 7
# Neighbour: [3, 3, 7, 1, 6, 1, 1, 1], Cost: 9
# Neighbour: [3, 4, 7, 1, 6, 1, 1, 1], Cost: 7
# Neighbour: [3, 5, 7, 1, 6, 1, 1, 1], Cost: 7
# Neighbour: [3, 6, 7, 1, 6, 1, 1, 1], Cost: 9
# Neighbour: [3, 7, 7, 1, 6, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 0, 1, 6, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 1, 1, 6, 1, 1, 1], Cost: 12
# Neighbour: [3, 0, 3, 1, 6, 1, 1, 1], Cost: 7
# Neighbour: [3, 0, 4, 1, 6, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 5, 1, 6, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 6, 1, 6, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 1], Cost: 6
# Neighbour: [3, 0, 7, 0, 6, 1, 1, 1], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 1], Cost: 6
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 1], Cost: 4
# Neighbour: [3, 0, 7, 4, 6, 1, 1, 1], Cost: 4
# Neighbour: [3, 0, 7, 5, 6, 1, 1, 1], Cost: 5
# Neighbour: [3, 0, 7, 6, 6, 1, 1, 1], Cost: 6
# Neighbour: [3, 0, 7, 7, 6, 1, 1, 1], Cost: 5
# Neighbour: [3, 0, 7, 1, 0, 1, 1, 1], Cost: 9
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 1], Cost: 10
# Neighbour: [3, 0, 7, 1, 2, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 7, 1, 3, 1, 1, 1], Cost: 9
# Neighbour: [3, 0, 7, 1, 5, 1, 1, 1], Cost: 7
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 1], Cost: 6
# Neighbour: [3, 0, 7, 1, 7, 1, 1, 1], Cost: 8
# Neighbour: [3, 0, 7, 1, 6, 0, 1, 1], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 1], Cost: 6
# Neighbour: [3, 0, 7, 1, 6, 2, 1, 1], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 3, 1, 1], Cost: 6
# Neighbour: [3, 0, 7, 1, 6, 4, 1, 1], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 6, 1, 1], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 7, 1, 1], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 1, 0, 1], Cost: 6
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 1], Cost: 6
# Neighbour: [3, 0, 7, 1, 6, 1, 2, 1], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 1, 3, 1], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 1, 4, 1], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 1, 5, 1], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 1, 7, 1], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 0], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 1], Cost: 6
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 2], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 3], Cost: 6
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 5], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 6], Cost: 5
#
# Iteration 5
# Current State: [3, 0, 7, 1, 6, 1, 1, 4], Cost: 3
# Neighbour: [1, 0, 7, 1, 6, 1, 1, 4], Cost: 7
# Neighbour: [2, 0, 7, 1, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 4], Cost: 3
# Neighbour: [4, 0, 7, 1, 6, 1, 1, 4], Cost: 5
# Neighbour: [5, 0, 7, 1, 6, 1, 1, 4], Cost: 4
# Neighbour: [6, 0, 7, 1, 6, 1, 1, 4], Cost: 5
# Neighbour: [7, 0, 7, 1, 6, 1, 1, 4], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 2, 7, 1, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 3, 7, 1, 6, 1, 1, 4], Cost: 6
# Neighbour: [3, 4, 7, 1, 6, 1, 1, 4], Cost: 5
# Neighbour: [3, 5, 7, 1, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 6, 7, 1, 6, 1, 1, 4], Cost: 6
# Neighbour: [3, 7, 7, 1, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 0, 1, 6, 1, 1, 4], Cost: 5
# Neighbour: [3, 0, 1, 1, 6, 1, 1, 4], Cost: 8
# Neighbour: [3, 0, 3, 1, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 4, 1, 6, 1, 1, 4], Cost: 6
# Neighbour: [3, 0, 5, 1, 6, 1, 1, 4], Cost: 5
# Neighbour: [3, 0, 6, 1, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 0, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 0, 7, 4, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 5, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 0, 7, 6, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 7, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 0, 1, 1, 4], Cost: 6
# Neighbour: [3, 0, 7, 1, 1, 1, 1, 4], Cost: 7
# Neighbour: [3, 0, 7, 1, 2, 1, 1, 4], Cost: 5
# Neighbour: [3, 0, 7, 1, 3, 1, 1, 4], Cost: 6
# Neighbour: [3, 0, 7, 1, 5, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 7, 1, 1, 4], Cost: 6
# Neighbour: [3, 0, 7, 1, 6, 0, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 6, 2, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 6, 3, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 6, 4, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 6, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 6, 7, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 6, 1, 0, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 6, 1, 2, 4], Cost: 2
# Neighbour: [3, 0, 7, 1, 6, 1, 3, 4], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 1, 4, 4], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 1, 5, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 6, 1, 7, 4], Cost: 2
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 0], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 1], Cost: 6
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 2], Cost: 5
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 3], Cost: 6
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 5], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 6], Cost: 5
#
# Iteration 6
# Current State: [3, 0, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [1, 0, 7, 2, 6, 1, 1, 4], Cost: 5
# Neighbour: [2, 0, 7, 2, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [4, 0, 7, 2, 6, 1, 1, 4], Cost: 3
# Neighbour: [5, 0, 7, 2, 6, 1, 1, 4], Cost: 4
# Neighbour: [6, 0, 7, 2, 6, 1, 1, 4], Cost: 4
# Neighbour: [7, 0, 7, 2, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 2, 7, 2, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 3, 7, 2, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 4, 7, 2, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 5, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 6, 7, 2, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 7, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 0, 0, 2, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 1, 2, 6, 1, 1, 4], Cost: 7
# Neighbour: [3, 0, 3, 2, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 4, 2, 6, 1, 1, 4], Cost: 5
# Neighbour: [3, 0, 5, 2, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 6, 2, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 0, 7, 0, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 1, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 0, 7, 4, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 5, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 0, 7, 6, 6, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 7, 6, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 2, 0, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 2, 1, 1, 1, 4], Cost: 6
# Neighbour: [3, 0, 7, 2, 2, 1, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 2, 3, 1, 1, 4], Cost: 6
# Neighbour: [3, 0, 7, 2, 5, 1, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 0, 7, 2, 7, 1, 1, 4], Cost: 5
# Neighbour: [3, 0, 7, 2, 6, 0, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 0, 7, 2, 6, 2, 1, 4], Cost: 4
# Neighbour: [3, 0, 7, 2, 6, 3, 1, 4], Cost: 2
# Neighbour: [3, 0, 7, 2, 6, 4, 1, 4], Cost: 5
# Neighbour: [3, 0, 7, 2, 6, 6, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 2, 6, 7, 1, 4], Cost: 3
# Neighbour: [3, 0, 7, 2, 6, 1, 0, 4], Cost: 3
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 0, 7, 2, 6, 1, 2, 4], Cost: 3
# Neighbour: [3, 0, 7, 2, 6, 1, 3, 4], Cost: 4
# Neighbour: [3, 0, 7, 2, 6, 1, 4, 4], Cost: 3
# Neighbour: [3, 0, 7, 2, 6, 1, 5, 4], Cost: 4
# Neighbour: [3, 0, 7, 2, 6, 1, 7, 4], Cost: 2
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 0], Cost: 4
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 1], Cost: 4
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 2], Cost: 5
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 3], Cost: 5
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 4], Cost: 2
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 5], Cost: 2
# Neighbour: [3, 0, 7, 2, 6, 1, 1, 6], Cost: 5
#
# Final Results
# Initial State: [1, 1, 1, 1, 1, 1, 1, 1]
# Final State (Solution): [3, 0, 7, 2, 6, 1, 1, 4]
# Final Cost (Attacking Pairs): 2
# Local optimum reached, but no solution.
